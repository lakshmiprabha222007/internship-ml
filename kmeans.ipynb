# %%
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

# %%
# Assuming 'X' is your data array (from the kernel state)
# Let's choose an arbitrary number of clusters, e.g., 3
kmeans = KMeans(n_clusters=3, random_state=0, n_init=10) # n_init is set to suppress a warning
kmeans.fit(X)

# Get cluster labels and centroids
labels = kmeans.labels_
centroids = kmeans.cluster_centers_

print("Cluster Labels:")
print(labels)
print("\nCluster Centroids:")
print(centroids)
# Out:
# Cluster Labels:
# [1 1 1 0 0 0 2 2 2]
#
# Cluster Centroids:
# [[77.66666667 78.66666667]
#  [40.         42.66666667]
#  [90.         91.66666667]]

# %%
# Plot the results
plt.figure(figsize=(8, 6))

# Plot data points, colored by cluster
plt.scatter(X[:, 0], X[:, 1], c=labels, cmap='viridis', s=50, alpha=0.8, label='Data Points')

# Plot centroids
plt.scatter(centroids[:, 0], centroids[:, 1], c='red', marker='X', s=200, label='Centroids')

plt.title('K-Means Clustering of X')
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.legend()
plt.grid(True)
plt.show()
